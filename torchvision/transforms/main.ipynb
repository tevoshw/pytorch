# %% [markdown]
# # 1. Transforms
#
# Transforms it's the module of torchvision that preprocessing of images data. A lib torchvision não aceita em si, fotos como .JPEG ou .PNG, basicamente devemos usar a lib PIL (PILLOW) para isso aonde, permite que lemos imagens e possamos transforma-las
#
#
# ```python
#
# from torchvision.transforms import v2
#
#
# ```
#
# ---
#
# ## 1.1 Transforms Compose
#
# Allows that you compose more than 1 transformation
#
# ```python
#
# transforms_v2 = v2.Compose([
#     v2.Resize((256, 256)), # Transformation 1
#     v2.CenterCrop(size=(224, 224)), # Transformation 2
#     v2.ToDtype(torch.float32, scale=True), # Transformation 3
# ])
#
# ```
#
# ---
#
# ## 1.2 Transforms ToImage
#
# Transform a PIL Object or Numpy into a tensor for pytorch. Mantem os pixels entre numeros de 0-255 (int)
#
#
# ```python
#
# to_image = v2.ToImage()
#
# img_tensor = to_image(img)
#
#
# ```
#
# ---
#
# ## 1.3 Transforms Resize
#
# The most common transformation, altera as dimensões (altura e largura)
#
#
# ```python
#
#
# resize = v2.Resize(
#     size = (HEIGHT, WEIGHT) # The new dimensions that the image gonna have
# )
#
# image_reshaped = resize(image)
#
#
# ```
#
#
# ---
#
# ## 1.4 Transforms Dtype
#
# Transform the dtype of a matrix, and can reescale the values of the tensors
#
# ```python
#
# dtype = v2.Dtype(
#     dtype = torch.float32, # Transform the dtype
#     scale = True, # Reescale the tesnors (0-255 -> 0.0-1)
# )
#
# image_new_dtype = dtype(image)
#
# ```
# ---
#
# ## 1.5 Transforms Normalize
#
# Normalize the value of tensors
#
#
# ```python
#
# normalize = v2.Normalize(
#     mean = [],
#     std =[]
# )
#
#
# image_normalize = normalize(image)
#
# ```
