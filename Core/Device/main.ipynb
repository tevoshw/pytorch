# %%
import torch

print(f'Torch its avaliable?: {torch.cuda.is_available()}')
print(f'Actual cuda device: {torch.cuda.current_device()} ')
print(f'Name of the first GPU: {torch.cuda.get_device_name(0)}')
print(f'How many GPUS exist?: {torch.cuda.device_count()}')
# Out:
# Torch its avaliable?: True
# Actual cuda device: 0
# Name of the first GPU: NVIDIA GeForce GTX 1650
# How many GPUS exist?: 1

# %%
before = torch.tensor(2)
print(f'Before the default: {before.device}')
# Out:
# Before the default: cuda:0

# %%
print(f'After the default: {after.device}')
torch.set_default_device('cuda')
after = torch.tensor(2)
# Out:
# After the default: cuda:0
